# %%
import pandas as pd
import numpy as np 
from tsfresh import select_features
from tsfresh.utilities.dataframe_functions import impute
from tsfresh import extract_features

# %%
from tsfresh.examples.robot_execution_failures import download_robot_execution_failures, \
    load_robot_execution_failures
download_robot_execution_failures()
timeseries, y = load_robot_execution_failures()

print(timeseries.head())
# Out:
# id  time  F_x  F_y  F_z  T_x  T_y  T_z
# 0   1     0   -1   -1   63   -3   -1    0
# 1   1     1    0    0   62   -3   -1    0
# 2   1     2   -1   -1   61   -3    0    0
# 3   1     3   -1   -1   63   -2   -1    0
# 4   1     4   -1   -1   63   -3   -1    0

# %%
import matplotlib.pyplot as plt
timeseries[timeseries['id'] == 21].plot(subplots=True, sharex=True, figsize=(10,10))
plt.show()

# %%
from tsfresh import extract_features
extracted_features = extract_features(timeseries, column_id="id", column_sort="time")
# Out:
# Feature Extraction: 100%|██████████| 10/10 [00:16<00:00,  1.61s/it]

# %%
len(features_filtered)
# Out:
# 88

# %%
avocado = pd.read_csv('avocado.csv')

prices = avocado[["AveragePrice","Total Volume"]]
prices['id'] = range(0, len(prices))

# %%
for index,row in prices.iterrows():
    prices.loc[index,'event'] = np.random.randint(0, 10)

# %%
prices
# Out:
#        AveragePrice  Total Volume     id  event
# 0              1.33      64236.62      0    4.0
# 1              1.35      54876.98      1    7.0
# 2              0.93     118220.22      2    0.0
# 3              1.08      78992.15      3    7.0
# 4              1.28      51039.60      4    2.0
# ...             ...           ...    ...    ...
# 18244          1.63      17074.83  18244    6.0
# 18245          1.71      13888.04  18245    7.0
# 18246          1.87      13766.76  18246    9.0
# 18247          1.93      16205.22  18247    9.0
# 18248          1.62      17489.58  18248    7.0
#
# [18249 rows x 4 columns]

# %%
extracted_features = extract_features(prices, column_id="event")
# Out:
# Feature Extraction: 100%|██████████| 10/10 [00:53<00:00,  5.31s/it]

# %%
extracted_features.columns
# Out:
# Index(['AveragePrice__abs_energy', 'AveragePrice__absolute_sum_of_changes',
#        'AveragePrice__agg_autocorrelation__f_agg_"mean"__maxlag_40',
#        'AveragePrice__agg_autocorrelation__f_agg_"median"__maxlag_40',
#        'AveragePrice__agg_autocorrelation__f_agg_"var"__maxlag_40',
#        'AveragePrice__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"',
#        'AveragePrice__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"',
#        'AveragePrice__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"',
#        'AveragePrice__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"',
#        'AveragePrice__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"',
#        ...
#        'id__symmetry_looking__r_0.9500000000000001',
#        'id__time_reversal_asymmetry_statistic__lag_1',
#        'id__time_reversal_asymmetry_statistic__lag_2',
#        'id__time_reversal_asymmetry_statistic__lag_3',
# ...
